# %% [markdown]
# # IMAGE PROCESSING

# %%
import pandas as pd

from warnings import filterwarnings
filterwarnings("ignore")

import matplotlib.pyplot as plt

# %%
import cv2

# %%
A = cv2.imread("C:/Users/Pawan/Desktop/stillweb/urls_images//PIX-0427-1.jpg")

# %%
A.shape
# Out:
# (507, 640, 3)

# %%
plt.imshow(A)

# %%
B = cv2.cvtColor(A,cv2.COLOR_BGR2GRAY)
plt.imshow(B)

# %%
B
# Out:
# array([[ 79,  76,  77, ..., 251, 251, 251],
#        [ 85,  75,  75, ..., 251, 251, 251],
#        [ 81,  74,  75, ..., 251, 251, 251],
#        ...,
#        [156, 156, 158, ..., 184, 183, 182],
#        [155, 155, 158, ..., 185, 184, 183],
#        [154, 154, 156, ..., 186, 185, 184]], dtype=uint8)

# %%
B.shape
# Out:
# (507, 640)

# %%
Q = []
for i in range(0,507):
    for j in range(0,640):
        Q.append(B[i,j])

# %%
Q
# Out:
# [79,
#  76,
#  77,
#  70,
#  65,
#  65,
#  64,
#  70,
#  65,
#  49,
#  39,
#  76,
#  52,
#  23,
#  41,
#  49,
#  38,
#  33,
#  26,
#  46,
#  27,
#  64,
#  49,
#  32,
#  45,
#  37,
#  31,
#  46,
#  35,
#  29,
#  32,
#  41,
#  57,
#  67,
#  70,
#  66,
#  48,
#  33,
#  35,
#  34,
#  47,
#  46,
#  44,
#  50,
#  74,
#  76,
#  74,
#  58,
#  45,
#  35,
#  38,
#  44,
#  57,
#  47,
#  51,
#  64,
#  52,
#  52,
#  53,
#  51,
#  49,
#  37,
#  47,
#  51,
#  47,
#  63,
#  53,
#  45,
#  42,
#  49,
#  42,
#  47,
#  40,
#  45,
#  50,
#  46,
#  54,
#  47,
#  42,
#  55,
#  73,
#  65,
#  55,
#  42,
#  48,
#  42,
#  64,
#  59,
#  39,
#  64,
#  65,
#  47,
#  48,
#  50,
#  45,
#  60,
#  65,
#  44,
#  66,
#  63,
#  44,
#  41,
#  51,
#  42,
#  65,
#  61,
#  53,
#  46,
#  50,
#  52,
#  53,
#  65,
#  43,
#  46,
#  58,
#  52,
#  40,
#  34,
#  61,
#  44,
#  38,
#  39,
#  61,
#  59,
#  53,
#  52,
#  39,
#  43,
#  40,
#  50,
#  71,
#  58,
#  52,
#  68,
#  42,
#  47,
#  47,
#  49,
#  56,
#  41,
#  36,
#  54,
#  56,
#  56,
#  53,
#  39,
#  43,
#  46,
#  35,
#  44,
#  55,
#  34,
#  60,
#  61,
#  47,
#  41,
#  39,
#  57,
#  73,
#  40,
#  34,
#  43,
#  38,
#  47,
#  59,
#  56,
#  53,
#  46,
#  46,
#  46,
#  39,
#  62,
#  57,
#  67,
#  65,
#  53,
#  58,
#  47,
#  39,
#  58,
#  70,
#  53,
#  47,
#  55,
#  67,
#  60,
#  54,
#  44,
#  48,
#  67,
#  69,
#  62,
#  57,
#  100,
#  89,
#  72,
#  60,
#  51,
#  61,
#  42,
#  56,
#  69,
#  44,
#  79,
#  69,
#  49,
#  59,
#  54,
#  49,
#  76,
#  79,
#  76,
#  66,
#  58,
#  60,
#  54,
#  43,
#  64,
#  64,
#  55,
#  55,
#  43,
#  73,
#  54,
#  70,
#  40,
#  59,
#  71,
#  42,
#  52,
#  60,
#  52,
#  58,
#  60,
#  51,
#  68,
#  71,
#  48,
#  59,
#  80,
#  92,
#  66,
#  69,
#  70,
#  85,
#  65,
#  59,
#  78,
#  81,
#  58,
#  63,
#  71,
#  55,
#  67,
#  53,
#  68,
#  50,
#  59,
#  55,
#  62,
#  66,
#  66,
#  95,
#  92,
#  63,
#  64,
#  58,
#  56,
#  55,
#  62,
#  71,
#  65,
#  113,
#  116,
#  97,
#  67,
#  71,
#  82,
#  79,
#  46,
#  59,
#  88,
#  98,
#  90,
#  101,
#  91,
#  58,
#  60,
#  71,
#  72,
#  104,
#  116,
#  102,
#  110,
#  123,
#  118,
#  222,
#  250,
#  250,
#  250,
#  248,
#  251,
#  250,
#  247,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  251,
#  251,
#  250,
#  250,
#  250,
#  249,
#  250,
#  252,
#  237,
#  231,
#  230,
#  219,
#  221,
#  220,
#  218,
#  218,
#  219,
#  215,
#  222,
#  228,
#  211,
#  211,
#  213,
#  214,
#  211,
#  209,
#  209,
#  210,
#  210,
#  212,
#  207,
#  207,
#  212,
#  214,
#  209,
#  205,
#  204,
#  206,
#  209,
#  210,
#  211,
#  213,
#  211,
#  209,
#  213,
#  214,
#  214,
#  213,
#  213,
#  214,
#  216,
#  215,
#  212,
#  212,
#  214,
#  214,
#  211,
#  211,
#  215,
#  217,
#  217,
#  217,
#  215,
#  214,
#  215,
#  216,
#  216,
#  217,
#  219,
#  222,
#  225,
#  216,
#  212,
#  224,
#  215,
#  215,
#  217,
#  220,
#  219,
#  208,
#  206,
#  209,
#  205,
#  205,
#  203,
#  214,
#  157,
#  138,
#  128,
#  121,
#  146,
#  139,
#  139,
#  138,
#  139,
#  140,
#  139,
#  141,
#  143,
#  143,
#  232,
#  219,
#  133,
#  213,
#  202,
#  210,
#  232,
#  222,
#  214,
#  212,
#  216,
#  217,
#  216,
#  217,
#  221,
#  222,
#  219,
#  208,
#  210,
#  211,
#  211,
#  210,
#  210,
#  211,
#  211,
#  209,
#  211,
#  218,
#  215,
#  213,
#  235,
#  250,
#  244,
#  251,
#  243,
#  225,
#  224,
#  230,
#  214,
#  211,
#  239,
#  252,
#  213,
#  208,
#  208,
#  203,
#  208,
#  203,
#  203,
#  203,
#  184,
#  161,
#  147,
#  145,
#  145,
#  142,
#  137,
#  137,
#  137,
#  133,
#  123,
#  132,
#  131,
#  143,
#  153,
#  93,
#  144,
#  140,
#  215,
#  182,
#  85,
#  106,
#  108,
#  103,
#  100,
#  102,
#  99,
#  87,
#  89,
#  84,
#  97,
#  93,
#  93,
#  92,
#  90,
#  90,
#  92,
#  91,
#  90,
#  90,
#  89,
#  87,
#  87,
#  87,
#  86,
#  84,
#  83,
#  84,
#  86,
#  85,
#  80,
#  78,
#  78,
#  76,
#  72,
#  77,
#  75,
#  74,
#  74,
#  73,
#  72,
#  72,
#  74,
#  75,
#  74,
#  74,
#  73,
#  72,
#  72,
#  71,
#  71,
#  68,
#  67,
#  68,
#  70,
#  70,
#  68,
#  66,
#  65,
#  65,
#  65,
#  64,
#  64,
#  65,
#  65,
#  65,
#  64,
#  64,
#  65,
#  65,
#  64,
#  63,
#  62,
#  62,
#  63,
#  62,
#  61,
#  60,
#  60,
#  60,
#  60,
#  58,
#  57,
#  58,
#  62,
#  62,
#  57,
#  58,
#  62,
#  61,
#  56,
#  58,
#  59,
#  60,
#  59,
#  57,
#  57,
#  58,
#  60,
#  59,
#  59,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  63,
#  62,
#  60,
#  59,
#  59,
#  61,
#  62,
#  64,
#  61,
#  63,
#  60,
#  58,
#  61,
#  61,
#  60,
#  63,
#  62,
#  63,
#  63,
#  64,
#  66,
#  67,
#  68,
#  69,
#  69,
#  71,
#  70,
#  71,
#  73,
#  71,
#  69,
#  74,
#  78,
#  76,
#  83,
#  77,
#  180,
#  254,
#  249,
#  249,
#  250,
#  250,
#  250,
#  251,
#  251,
#  251,
#  251,
#  251,
#  85,
#  75,
#  75,
#  74,
#  71,
#  69,
#  70,
#  83,
#  74,
#  66,
#  60,
#  53,
#  54,
#  23,
#  39,
#  49,
#  33,
#  35,
#  30,
#  47,
#  33,
#  46,
#  48,
#  37,
#  41,
#  36,
#  33,
#  48,
#  38,
#  29,
#  30,
#  38,
#  54,
#  61,
#  64,
#  66,
#  54,
#  36,
#  33,
#  35,
#  49,
#  46,
#  43,
#  51,
#  73,
#  71,
#  69,
#  57,
#  44,
#  36,
#  37,
#  36,
#  53,
#  53,
#  52,
#  62,
#  57,
#  54,
#  56,
#  55,
#  49,
#  37,
#  47,
#  48,
#  43,
#  59,
#  50,
#  40,
#  38,
#  45,
#  40,
#  42,
#  41,
#  46,
#  51,
#  46,
#  56,
#  49,
#  44,
#  54,
#  73,
#  68,
#  54,
#  38,
#  43,
#  37,
#  60,
#  61,
#  41,
#  63,
#  62,
#  43,
#  47,
#  50,
#  46,
#  60,
#  68,
#  45,
#  64,
#  62,
#  45,
#  41,
#  49,
#  40,
#  64,
#  59,
#  51,
#  48,
#  54,
#  53,
#  51,
#  60,
#  46,
#  47,
#  58,
#  50,
#  39,
#  35,
#  63,
#  48,
#  38,
#  46,
#  59,
#  53,
#  50,
#  52,
#  42,
#  41,
#  40,
#  48,
#  69,
#  56,
#  50,
#  67,
#  42,
#  48,
#  49,
#  47,
#  56,
#  42,
#  34,
#  50,
#  54,
#  53,
#  53,
#  39,
#  40,
#  41,
#  32,
#  45,
#  53,
#  30,
#  60,
#  62,
#  48,
#  42,
#  38,
#  56,
#  74,
#  43,
#  35,
#  44,
#  39,
#  44,
#  57,
#  57,
#  52,
#  43,
#  46,
#  49,
#  38,
#  59,
#  54,
#  67,
#  70,
#  50,
#  52,
#  42,
#  40,
#  66,
#  77,
#  53,
#  46,
#  60,
#  62,
#  58,
#  56,
#  46,
#  48,
#  64,
#  64,
#  57,
#  63,
#  101,
#  95,
#  77,
#  56,
#  57,
#  54,
#  41,
#  53,
#  75,
#  51,
#  77,
#  69,
#  54,
#  64,
#  56,
#  49,
#  74,
#  78,
#  76,
#  66,
#  55,
#  56,
#  49,
#  49,
#  63,
#  60,
#  53,
#  55,
#  48,
#  74,
#  47,
#  69,
#  45,
#  54,
#  68,
#  42,
#  53,
#  60,
#  50,
#  50,
#  67,
#  58,
#  67,
#  73,
#  52,
#  57,
#  79,
#  92,
#  66,
#  71,
#  74,
#  87,
#  63,
#  57,
#  78,
#  76,
#  58,
#  68,
#  80,
#  50,
#  64,
#  69,
#  71,
#  51,
#  60,
#  72,
#  63,
#  69,
#  68,
#  90,
#  86,
#  61,
#  62,
#  58,
#  55,
#  54,
#  60,
#  70,
#  65,
#  106,
#  114,
#  97,
#  68,
#  72,
#  84,
#  82,
#  52,
#  56,
#  88,
#  95,
#  85,
#  108,
#  93,
#  57,
#  60,
#  72,
#  73,
#  97,
#  112,
#  103,
#  110,
#  124,
#  115,
#  207,
#  251,
#  249,
#  251,
#  248,
#  250,
#  251,
#  249,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  251,
#  251,
#  250,
#  250,
#  250,
#  250,
#  251,
#  242,
#  232,
#  229,
#  227,
#  225,
#  221,
#  216,
#  216,
#  217,
#  216,
#  211,
#  219,
#  228,
#  213,
#  212,
#  213,
#  214,
#  212,
#  211,
#  210,
#  209,
#  207,
#  208,
#  209,
#  209,
#  210,
#  212,
#  212,
#  210,
#  207,
#  208,
#  211,
#  211,
#  212,
#  212,
#  210,
#  210,
#  215,
#  ...]

# %%
A = pd.DataFrame(Q).T

# %%
A
# Out:
#    0       1       2       3       4       5       6       7       8       \
# 0      79      76      77      70      65      65      64      70      65
#
#    9       ...  324470  324471  324472  324473  324474  324475  324476  \
# 0      49  ...     -70     -82     -77     -75     -73     -71     -70
#
#    324477  324478  324479
# 0     -70     -71     -72
#
# [1 rows x 324480 columns]

# %%
A.loc[1] = Q

# %%
A
# Out:
#    0       1       2       3       4       5       6       7       8       \
# 0      79      76      77      70      65      65      64      70      65
# 1      79      76      77      70      65      65      64      70      65
#
#    9       ...  324470  324471  324472  324473  324474  324475  324476  \
# 0      49  ...     -70     -82     -77     -75     -73     -71     -70
# 1      49  ...     -70     -82     -77     -75     -73     -71     -70
#
#    324477  324478  324479
# 0     -70     -71     -72
# 1     -70     -71     -72
#
# [2 rows x 324480 columns]
